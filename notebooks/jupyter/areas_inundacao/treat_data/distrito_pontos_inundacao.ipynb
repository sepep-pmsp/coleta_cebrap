# %%
from configuracoes_notebooks import set_proj_dir
set_proj_dir()
# Out:
# O diretorio do seu projeto é coleta_cebrap
# Caminho absoluto do diretorio encontrado C:\Users\x526378\Desktop\projetos\cebrap\coleta_cebrap
# Caminho no path.

# %%
import geopandas as gpd
import os

from notebooks.jupyter import utils
from utils import get_data_diretorio
from utils.downloads import download_malha_geosampa

# %% [markdown]
# # Risco de Ocorrência de Inundação por Distrito

# %%
data_path= get_data_diretorio()

# %% [markdown]
# # Dependências

# %%
gdf_distrito = gpd.read_parquet(
    os.path.join(
        data_path,
        'assets',
        'distrito_ibge.parquet'
    )
)

# %%
gdf_pontos_inund = gpd.read_parquet(
    os.path.join(
        data_path,
        'assets',
        'pontos_risco_inundacao.parquet'
    )
)

# %%
gdf_pontos_inund.sample(3)
# Out:
#     cd_inund_risco dt_ocorren                       nm_subpref  \
# 38             906 2025-02-01         MP - SAO MIGUEL PAULISTA
# 281            716 2025-01-27  FO - FREGUESIA DO O/BRASILANDIA
# 219            165 2025-01-07                    IQ - ITAQUERA
#
#                            geometry
# 38   POINT (352074.159 7401661.901)
# 281  POINT (327373.855 7405630.384)
# 219  POINT (348208.533 7391523.675)

# %%
gdf_pontos_inund
