# %%
from configuracoes_notebooks import set_proj_dir
set_proj_dir()
# Out:
# O diretorio do seu projeto é coleta_cebrap
# Caminho absoluto do diretorio encontrado C:\Users\x526378\Desktop\projetos\cebrap\coleta_cebrap
# Caminho no path.

# %%
from notebooks.jupyter import utils
from utils import (
    get_data_diretorio,
)
from utils.downloads import download_malha_geosampa

# %% [markdown]
# Eu ainda não tenho certeza de quais camadas devo pegar, vou pegar todas e comparar

# %%
data_path = get_data_diretorio()

# %% [markdown]
# # Risco de Ocorrência de Inundação

# %%
gdf_risco_inund= download_malha_geosampa(
    'risco_ocorrencia_inundacao', 
    data_path
)
# Out:
# helloo
# C:\Users\x526378\Desktop\projetos\cebrap\coleta_cebrap\data\cache\risco_ocorrencia_inundacao.zip

# %%
gdf_risco_inund
# Out:
#     cd_identif dt_ocorren dc_tipo_oc nm_distrit   dt_carga  \
# 0          860 2025-02-01  INUNDACAO       None 2025-03-14
# 1          861 2025-02-01  INUNDACAO       None 2025-03-14
# 2          862 2025-02-01  INUNDACAO       None 2025-03-14
# 3          863 2025-02-01  INUNDACAO       None 2025-03-14
# 4          864 2025-02-01  INUNDACAO       None 2025-03-14
# ..         ...        ...        ...        ...        ...
# 303        818 2025-01-30  INUNDACAO       None 2025-03-14
# 304        836 2025-01-31  INUNDACAO       None 2025-03-14
# 305        847 2025-01-31  INUNDACAO       None 2025-03-14
# 306        848 2025-01-31  INUNDACAO       None 2025-03-14
# 307        852 2025-01-31  INUNDACAO       None 2025-03-14
#
#                        nm_subpref sg_fonte_o                        geometry
# 0    CV - CASA VERDE/CACHOEIRINHA      SIGRC    POINT (331103.8 7404600.303)
# 1            JT - JACANA/TREMEMBE      SIGRC  POINT (334300.632 7405527.031)
# 2            JT - JACANA/TREMEMBE      SIGRC  POINT (333698.739 7405687.768)
# 3                   IQ - ITAQUERA      SIGRC  POINT (351426.915 7398377.402)
# 4        MP - SAO MIGUEL PAULISTA      SIGRC  POINT (351183.574 7401614.381)
# ..                            ...        ...                             ...
# 303           IT - ITAIM PAULISTA      SIGRC  POINT (359334.205 7402156.146)
# 304              PA - PARELHEIROS      SIGRC  POINT (324534.207 7369689.189)
# 305              CL - CAMPO LIMPO      SIGRC  POINT (321991.868 7384688.704)
# 306              CL - CAMPO LIMPO      SIGRC  POINT (323590.628 7387189.531)
# 307              CL - CAMPO LIMPO      SIGRC  POINT (324000.016 7387474.054)
#
# [308 rows x 8 columns]
